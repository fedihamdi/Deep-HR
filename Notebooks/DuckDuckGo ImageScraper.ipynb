# %% [markdown]
# # DuckDuckGo Image Scraper
#
# This was originally an image scraper notebook for creating deep learning datasets.
#
# It has since been turned into an installable library and is much easier to use as you can simply drop a few lines of code into your own notebook as you're experimenting.
#
# This notebook now shows you how to use the library.
#
# Docs are at [joedockrill.github.io/jmd_imagescraper/](https://joedockrill.github.io/jmd_imagescraper/)
#
# Hugs & kisses, Joe Dockrill.

# %% [markdown]
# ## Install

# %%
# !pip install -q jmd_imagescraper

# %% [markdown]
# ## Download images

# %%
from pathlib import Path
root = Path().cwd()/"images"

from jmd_imagescraper.core import * # dont't worry, it's designed to work with import *

# duckduckgo_search(root, "Cats", "cute kittens", max_results=10)
# duckduckgo_search(root, "Dogs", "cute puppies", max_results=10)
# duckduckgo_search(root, "Birds", "cute baby ducks and chickens", max_results=10)
duckduckgo_search(root, "people", "portrait photography linkedin", max_results=100)
# file paths are returned so if you want to snag a list of downloaded files as you go, do this:

# images = []
# images.extend(duckduckgo_search(root, "Cats", "cute kittens", max_results=10))
# images.extend(duckduckgo_search(root, "Dogs", "cute puppies", max_results=10))
# images.extend(duckduckgo_search(root, "Birds", "cute baby ducks and chickens", max_results=10))
# images
# Out:
# Duckduckgo search: portrait photography linkedin
# Downloading results into /content/images/people
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:08<00:00 Images downloaded]
#     </div>
# [PosixPath('/content/images/people/001_3494ed2a.jpg'),
#  PosixPath('/content/images/people/002_c645e58d.jpg'),
#  PosixPath('/content/images/people/003_1a895d91.jpg'),
#  PosixPath('/content/images/people/004_85b5c267.jpg'),
#  PosixPath('/content/images/people/005_7fa149ab.jpg'),
#  PosixPath('/content/images/people/006_bf12f046.jpg'),
#  PosixPath('/content/images/people/007_c84010a5.jpg'),
#  PosixPath('/content/images/people/008_684738f0.jpg'),
#  PosixPath('/content/images/people/009_8014795e.jpg'),
#  PosixPath('/content/images/people/010_b5cdcbd0.jpg'),
#  PosixPath('/content/images/people/011_fbc682c6.jpg'),
#  PosixPath('/content/images/people/012_51af085f.jpg'),
#  PosixPath('/content/images/people/013_99290b2c.jpg'),
#  PosixPath('/content/images/people/014_e7aa6ddc.jpg'),
#  PosixPath('/content/images/people/015_9af6f5c9.jpg'),
#  PosixPath('/content/images/people/016_66b150fc.jpg'),
#  PosixPath('/content/images/people/017_dd1db495.jpg'),
#  PosixPath('/content/images/people/018_8c7afcc1.jpg'),
#  PosixPath('/content/images/people/019_2502519f.jpg'),
#  PosixPath('/content/images/people/020_5c4cf128.jpg'),
#  PosixPath('/content/images/people/021_1f360b12.jpg'),
#  PosixPath('/content/images/people/022_5baf69f9.jpg'),
#  PosixPath('/content/images/people/023_3b5daa0b.jpg'),
#  PosixPath('/content/images/people/024_2fb298a7.jpg'),
#  PosixPath('/content/images/people/025_e17c4a6f.jpg'),
#  PosixPath('/content/images/people/026_2faa4738.jpg'),
#  PosixPath('/content/images/people/027_0fa947f1.jpg'),
#  PosixPath('/content/images/people/028_125bc0cf.jpg'),
#  PosixPath('/content/images/people/029_fab0eb47.jpg'),
#  PosixPath('/content/images/people/030_edcb00dd.jpg'),
#  PosixPath('/content/images/people/031_baa3220b.jpg'),
#  PosixPath('/content/images/people/032_a0e83172.jpg'),
#  PosixPath('/content/images/people/033_49345176.jpg'),
#  PosixPath('/content/images/people/034_633c9358.jpg'),
#  PosixPath('/content/images/people/035_14fe5b7e.jpg'),
#  PosixPath('/content/images/people/036_e131ba5c.jpg'),
#  PosixPath('/content/images/people/037_9684caaf.jpg'),
#  PosixPath('/content/images/people/038_5671ebab.jpg'),
#  PosixPath('/content/images/people/039_714d3e98.jpg'),
#  PosixPath('/content/images/people/040_b582e16a.jpg'),
#  PosixPath('/content/images/people/041_9d7634c3.jpg'),
#  PosixPath('/content/images/people/042_40f3721d.jpg'),
#  PosixPath('/content/images/people/043_4e8aa275.jpg'),
#  PosixPath('/content/images/people/044_1302ad9d.jpg'),
#  PosixPath('/content/images/people/045_5560c4c0.jpg'),
#  PosixPath('/content/images/people/046_768b8821.jpg'),
#  PosixPath('/content/images/people/047_2cacce7f.jpg'),
#  PosixPath('/content/images/people/048_8129c282.jpg'),
#  PosixPath('/content/images/people/049_3f360810.jpg'),
#  PosixPath('/content/images/people/050_1130a4e5.jpg'),
#  PosixPath('/content/images/people/051_741d7deb.jpg'),
#  PosixPath('/content/images/people/052_35d28da8.jpg'),
#  PosixPath('/content/images/people/053_3eaf56e5.jpg'),
#  PosixPath('/content/images/people/054_493a728d.jpg'),
#  PosixPath('/content/images/people/055_eab28ced.jpg'),
#  PosixPath('/content/images/people/056_7de9be99.jpg'),
#  PosixPath('/content/images/people/057_b13ed881.jpg'),
#  PosixPath('/content/images/people/058_c195fa3c.jpg'),
#  PosixPath('/content/images/people/059_c121a1d1.jpg'),
#  PosixPath('/content/images/people/060_8a495a14.jpg'),
#  PosixPath('/content/images/people/061_e13ab398.jpg'),
#  PosixPath('/content/images/people/062_a3a8dedb.jpg'),
#  PosixPath('/content/images/people/063_c573c1b2.jpg'),
#  PosixPath('/content/images/people/064_2c644942.jpg'),
#  PosixPath('/content/images/people/065_852f7bb6.jpg'),
#  PosixPath('/content/images/people/066_35ed2e2f.jpg'),
#  PosixPath('/content/images/people/067_2de9b616.jpg'),
#  PosixPath('/content/images/people/068_51d36b3d.jpg'),
#  PosixPath('/content/images/people/069_5e87260c.jpg'),
#  PosixPath('/content/images/people/070_271fe42c.jpg'),
#  PosixPath('/content/images/people/071_2ed12ffa.jpg'),
#  PosixPath('/content/images/people/072_90fea9bf.jpg'),
#  PosixPath('/content/images/people/073_7a6e3356.jpg'),
#  PosixPath('/content/images/people/074_1a239c4e.jpg'),
#  PosixPath('/content/images/people/075_1e60316e.jpg'),
#  PosixPath('/content/images/people/076_cc6c491a.jpg'),
#  PosixPath('/content/images/people/077_bc1e1805.jpg'),
#  PosixPath('/content/images/people/078_95d9f871.jpg'),
#  PosixPath('/content/images/people/079_bd1200fc.jpg'),
#  PosixPath('/content/images/people/080_80e2a4a0.jpg'),
#  PosixPath('/content/images/people/081_f02f256c.jpg'),
#  PosixPath('/content/images/people/082_a1f4e596.jpg'),
#  PosixPath('/content/images/people/083_1df7786f.jpg'),
#  PosixPath('/content/images/people/084_b3e5b991.jpg'),
#  PosixPath('/content/images/people/085_316d1cf1.jpg'),
#  PosixPath('/content/images/people/086_1cc6e046.jpg'),
#  PosixPath('/content/images/people/087_96c1010f.jpg'),
#  PosixPath('/content/images/people/088_473a280b.jpg'),
#  PosixPath('/content/images/people/089_ec0ef438.jpg'),
#  PosixPath('/content/images/people/090_d1a7c907.jpg'),
#  PosixPath('/content/images/people/091_9aa60e17.jpg'),
#  PosixPath('/content/images/people/092_9a892c23.jpg'),
#  PosixPath('/content/images/people/093_62b0d2a2.jpg'),
#  PosixPath('/content/images/people/094_f723d1ca.jpg'),
#  PosixPath('/content/images/people/095_d2e1ded0.jpg'),
#  PosixPath('/content/images/people/096_89371a44.jpg'),
#  PosixPath('/content/images/people/097_07573bfc.jpg'),
#  PosixPath('/content/images/people/098_4a377e32.jpg'),
#  PosixPath('/content/images/people/099_b298a7a4.jpg'),
#  PosixPath('/content/images/people/100_bd82dbed.jpg')]

# %% [markdown]
# ## Changing params across multiple searches

# %%
# If you're going to override default params across multiple searches you can use a 
# dictionary like this (so you can change search params for the entire dataset once).

# params = {
#     "max_results": 10,             # this can go up to 477 at the time of writing
#     "img_size":    ImgSize.Cached, 
#     "img_type":    ImgType.Photo,
#     "img_layout":  ImgLayout.Square,
#     "img_color":   ImgColor.Purple
# }

# duckduckgo_search(root, "Nice", "nice clowns", **params)
# duckduckgo_search(root, "Scary", "scary clowns", **params)

# %% [markdown]
# ## Deleting all images

# %%
#rmtree(root)

# %% [markdown]
# ## Displaying the image cleaner
#
# Use this to get rid of unsuitable images without leaving your notebook

# %%
from jmd_imagescraper.imagecleaner import *

display_image_cleaner(root)
# Out:
# HBox(children=(Button(description='|<<', layout=Layout(width='60px'), style=ButtonStyle()), Button(description…
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…

# %% [markdown]
# ## Create a zip to download or transfer to google drive

# %%
# create zip

ZIP_NAME = "images.zip" # maybe change this?

# !rm -f {ZIP_NAME}
# !zip -q -r {ZIP_NAME} {root}

# %%
# download to your local system

from google.colab import files
files.download(ZIP_NAME)

# %%
# copy to google drive 

from google.colab import drive
import shutil

DESTINATION_FOLDER = "Datasets_images" # where would you like this in Google Drive?

drive.mount("/content/drive") 
folder = Path("/content/drive/My Drive/HETIC PFA")/DESTINATION_FOLDER
folder.mkdir(parents=True, exist_ok=True)

shutil.copyfile(ZIP_NAME, str(folder/ZIP_NAME))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/My Drive/HETIC PFA/Datasets_images/images.zip'

# %% [markdown]
# ## Create a CSV file of URLs
#
# If you'd rather distribute a file with the image URLs and labels and have people download the images themselves you can do so here.

# %%
CSV_NAME = "images.csv" # maybe change this?

# !rm -f {CSV_NAME}

csv = Path.cwd()/CSV_NAME
save_urls_to_csv(csv, "people", "portrait photography linkedin", max_results=100)
#save_urls_to_csv(csv, "Scary", "scary clowns", max_results=5)

# %%
# !pip install google_images_download
# Out:
# Collecting google_images_download
#   Downloading google_images_download-2.8.0.tar.gz (14 kB)
# Collecting selenium
#   Downloading selenium-4.1.5-py3-none-any.whl (979 kB)
#      |████████████████████████████████| 979 kB 10.6 MB/s
# Collecting urllib3[secure,socks]~=1.26
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 59.6 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.20.0-py3-none-any.whl (359 kB)
#      |████████████████████████████████| 359 kB 62.3 MB/s
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium->google_images_download) (2.10)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium->google_images_download) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium->google_images_download) (21.4.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium->google_images_download) (1.7.1)
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.8 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium->google_images_download) (2021.10.8)
# Collecting cryptography>=1.3.4
#   Downloading cryptography-37.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 48.1 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium->google_images_download) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium->google_images_download) (2.21)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium->google_images_download) (4.2.0)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14550 sha256=140bac3fca6a64a1fb1e521543781a97221f30f27201ed07f0d4ddb87c01536b
#   Stored in directory: /root/.cache/pip/wheels/e3/98/42/0d3a76d46cd5a6659afb2f5612d4908ca42d34060973d46727
# Successfully built google-images-download
# Installing collected packages: sniffio, outcome, h11, cryptography, async-generator, wsproto, urllib3, trio, pyOpenSSL, trio-websocket, selenium, google-images-download
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed async-generator-1.10 cryptography-37.0.2 google-images-download-2.8.0 h11-0.13.0 outcome-1.1.0 pyOpenSSL-22.0.0 selenium-4.1.5 sniffio-1.2.0 trio-0.20.0 trio-websocket-0.9.2 urllib3-1.26.9 wsproto-1.1.0

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"Polar bears,baloons,Beaches","limit":20,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = Polar bears
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 20 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
# Item no.: 2 --> Item name = baloons
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 20 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
# Item no.: 3 --> Item name = Beaches
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 20 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
# ({'Polar bears': [], 'baloons': [], 'Beaches': []}, 0)
